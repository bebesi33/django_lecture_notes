# %%
import pandas as pd
import sqlite3

# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "credit_calculator_02.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
import django
django.setup()

# %%
from main.models import DiscountValue, DiscountCondition, Insurance, IncomeTrh, Loan
all_models = [DiscountValue, DiscountCondition, Insurance, IncomeTrh, Loan]

# %%
for model_def in all_models:
    temp_df = pd.DataFrame(list(model_def.objects.values()))
    print(str(model_def))
    display(temp_df)
# Out:
# <class 'main.models.DiscountValue'>
#        loan_type                            discount_rate_id  \
# 0   free purpose          UniCredit Aktív-kamat_free purpose
# 1   free purpose  UniCredit Prémium Aktív-kamat_free purpose
# 2   free purpose          UniCredit TOP Prémium_free purpose
# 3   free purpose          UniCredit Aktív-kamat_free purpose
# 4   free purpose  UniCredit Prémium Aktív-kamat_free purpose
# 5   free purpose          UniCredit TOP Prémium_free purpose
# 6   housing loan          UniCredit Aktív-kamat_housing loan
# 7   housing loan  UniCredit Prémium Aktív-kamat_housing loan
# 8   housing loan          UniCredit TOP Prémium_housing loan
# 9   free purpose                      K&H basic_free purpose
# 10  free purpose                       K&H full_free purpose
#
#                  discount_name_id  term_trh_low  term_trh_upper  discount_rate
# 0           UniCredit Aktív-kamat             5              10           0.50
# ...
